# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder #sayısal verielere çevirme için
import matplotlib.pyplot as plt #görselleştirme için
import seaborn as sns #görselleştirme için
from sklearn.model_selection import train_test_split #veriyi eğitim ve test veri
# modelleri ekleyelim
from sklearn.linear_model import LinearRegression
from sklearn.tree import Decision TreeRegressor
from sklearn.ensemble import Random ForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# 1. Veri Setini Yükleyelim
df=pd.read_csv("turkey_car_market.csv")
# Veri setinin ilk 5 satırına bakalım 
df.head(5)
# Out:
#   İlan Tarihi   Marka Arac Tip Grubu             Arac Tip  Model Yıl  \
# 0  27/05/2020  Jaguar             XF  2.0 D Prestige Plus     2017.0
# 1  16/06/2020   Acura             CL                    -     2015.0
# 2  14/06/2020   Acura             CL                  2.2     1994.0
# 3  11/06/2020   Acura             CL                    -     2013.0
# 4  11/06/2020   Acura             CL                  2.2     2010.0
#
#    Yakıt Turu                Vites           CCM Beygir Gucu         Renk  \
# 0       Dizel       Otomatik Vites  1801-2000 cc  176-200 BG    Lacivert
# 1       Dizel  Yarı Otomatik Vites  1301-1600 cc  101-125 BG        Mavi
# 2  Benzin/LPG            Düz Vites  1301-1600 cc  101-125 BG     Turkuaz
# 3       Dizel            Düz Vites  1301-1600 cc   76-100 BG  Kahverengi
# 4       Dizel       Otomatik Vites  1801-2000 cc  151-175 BG       Beyaz
#
#           Kasa Tipi      Kimden  Durum      Km   Fiyat
# ...

# %%
df[df['Fiyat']>5000000]
# Out:
#      İlan Tarihi    Marka Arac Tip Grubu       Arac Tip  Model Yıl Yakıt Turu  \
# 3478  12/05/2020  Hyundai            I20  1.4 CRDI Jump     2013.0      Dizel
#
#           Vites              CCM Beygir Gucu    Renk         Kasa Tipi  \
# 3478  Düz Vites  1300 cc ve altı   76-100 BG  Beyaz   Hatchback 5 Kapı
#
#           Kimden  Durum      Km    Fiyat
# 3478  Sahibinden  2. El  140000  5086500

# %%
df=df.drop([3478], axis=0)

# %%
#3. Veri Görselleştirme
#matplotlib.pyplot ve seaborn import edilir
# Fiyat ve kilometre ilişkisini görselleştirelim plt.figure(figsize=(10,6))
plt.scatter(x='Km', y='Fiyat', data=df)
plt.title("Kilometre ve Fiyat Arasındaki İlişki")
plt.show()
# Fiyat ve araç yaşını görselleştirelim
plt.figure(figsize=(10,6))
sns.scatterplot(x='Model Yıl', y='Fiyat', data=df)
plt.title("Araç Yaşı ve Fiyat Arasındaki İlişki")
plt.show()
#
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 4
#       1 #3. Veri Görselleştirme
#       2 #matplotlib.pyplot ve seaborn import edilir
#       3 # Fiyat ve kilometre ilişkisini görselleştirelim plt.figure(figsize=(10,6))
# ----> 4 plt.scatter(x='Km', y='Fiyat', data=df)
#       5 plt.title("Kilometre ve Fiyat Arasındaki İlişki")
#       6 plt.show()
#
# NameError: name 'plt' is not defined
